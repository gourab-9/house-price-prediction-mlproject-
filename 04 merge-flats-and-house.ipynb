# %%
import numpy as np
import pandas as pd

# %%
flats = pd.read_csv('flats_cleaned.csv')
houses = pd.read_csv('house_cleaned.csv')

# %%
df = pd.concat([flats,houses],ignore_index=True)

# %%
df = df.sample(df.shape[0],ignore_index=True)

# %%
df.head()
# Out:
#                       property_name property_type                    society  \
# 0   3 BHK Flat in Sector 61 Gurgaon          flat        smart world orchard
# 1   1 BHK Flat in Sector 67 Gurgaon          flat      m3m one key resiments
# 2  3 BHK Flat in Sector 106 Gurgaon          flat                 paras dews
# 3   2 BHK Flat in Sector 85 Gurgaon          flat         ss the leaf3.8 ï¿½
# 4   2 BHK Flat in Sector 77 Gurgaon          flat  umang winter hills3.9 ï¿½
#
#    price  price_per_sqft    area  \
# 0   2.57         15766.0  1630.0
# 1   0.80         13115.0   610.0
# 2   1.25         10656.0  1173.0
# 3   1.10          6318.0  1741.0
# 4   0.75          5588.0  1342.0
#
#                                         areaWithType  bedRoom  bathroom  \
# 0                   Carpet area: 1630 (151.43 sq.m.)      3.0       3.0
# 1                   Built Up area: 610 (56.67 sq.m.)      1.0       1.0
# 2  Super Built up area 1900(176.52 sq.m.)Built Up...      3.0       4.0
# 3  Super Built up area 1741(161.74 sq.m.)Carpet a...      2.0       2.0
# 4  Super Built up area 1342(124.68 sq.m.)Built Up...      2.0       2.0
#
#   balcony           additionalRoom  \
# 0       2               study room
# 1       0            not available
# 2       3  study room,servant room
# 3      3+               store room
# 4       2               store room
#
#                                             address  floorNum      facing  \
# 0               Sector 61 Gurgaon, Gurgaon, Haryana       3.0  North-East
# 1    Sector 67, Sector 67 Gurgaon, Gurgaon, Haryana       0.0         NaN
# 2        A888, Sector 106 Gurgaon, Gurgaon, Haryana      14.0        East
# 3  Tower T - 2, Sector 85 Gurgaon, Gurgaon, Haryana       3.0  South-East
# 4          876, Sector 77 Gurgaon, Gurgaon, Haryana       8.0       South
#
#         agePossession                                    nearbyLocations  \
# 0  Under Construction  ['Sector 55-56 Metro station', 'Bestech Centra...
# 1           undefined  ['Global Foyer Mall', 'Dwarka Expressway', 'ST...
# 2     1 to 5 Year Old  ['MG Road Metro Station', 'NeoSquare Shopping ...
# 3     1 to 5 Year Old  ['Sapphire 83 Mall', 'Dwarka Expressway', 'Cen...
# 4     1 to 5 Year Old  ['Entertainland Mall', 'Delhi Jaipur Expresswa...
#
#                                          description  \
# 0  This beautiful 3 bhk flat in sector-61 gurgaon...
# 1  Best in class property available at sector 67 ...
# 2  Looking for a 3 bhk property for sale in gurga...
# 3  This 2 bhk flat is located in ss the leaf, whi...
# 4  2 bhk flat available for sell in umang winter ...
#
#                                       furnishDetails  \
# 0  ['3 AC', '1 Chimney', '1 Modular Kitchen', '1 ...
# 1                                                NaN
# 2                                                NaN
# 3  ['10 Light', '4 AC', 'No Bed', 'No Chimney', '...
# 4  ['2 Wardrobe', '1 Water Purifier', '4 Fan', '1...
#
#                                             features  \
# 0                                        ['Lift(s)']
# 1                                                NaN
# 2  ['Water purifier', 'Centrally Air Conditioned'...
# 3  ['Centrally Air Conditioned', 'Water purifier'...
# 4  ['Security / Fire Alarm', 'Power Back-up', 'Fe...
#
#                                               rating
# 0                                                NaN
# 1  ['Environment4 out of 5', 'Safety4 out of 5', ...
# 2                                                NaN
# 3  ['Green Area4.5 out of 5', 'Construction4.5 ou...
# 4  ['Green Area5 out of 5', 'Construction5 out of...

# %%
df.to_csv('gurgaon_properties.csv',index=False)
