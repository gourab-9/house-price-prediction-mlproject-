# %%
import numpy as np
import pandas as pd

# %%
flats = pd.read_csv('flats_cleaned.csv')
houses = pd.read_csv('house_cleaned.csv')

# %%
df = pd.concat([flats,houses],ignore_index=True)

# %%
df = df.sample(df.shape[0],ignore_index=True)

# %%
df.head()
# Out:
#                                    property_name property_type       society  \
# 0  2 Bedroom House for sale in Sector 89 Gurgaon         house   greenopolis
# 1                3 BHK Flat in Sector 69 Gurgaon          flat  tulip violet
# 2        5 Bedroom House for sale in Palam Vihar         house   independent
# 3  9 Bedroom House for sale in Sector 9A Gurgaon         house   independent
# 4               4 BHK Flat in Sector 37D Gurgaon          flat    bptp terra
#
#    price  price_per_sqft    area  \
# 0   0.70          5397.0  1297.0
# 1   1.75          9459.0  1850.0
# 2   6.00         24691.0  2430.0
# 3   4.50         14286.0  3150.0
# 4   1.65          7530.0  2191.0
#
#                                         areaWithType  bedRoom  bathroom  \
# 0                  Built Up area: 1297 (120.5 sq.m.)        2         2
# 1                   Carpet area: 1850 (171.87 sq.m.)        3         4
# 2                        Plot area 270(225.75 sq.m.)        5         6
# 3                          Plot area 14(354.1 sq.m.)        9         9
# 4  Super Built up area 2191(203.55 sq.m.)Built Up...        4         3
#
#   balcony                additionalRoom  \
# 0       2                 not available
# 1       2                 not available
# 2      3+  pooja room,study room,others
# 3      3+  pooja room,study room,others
# 4      3+                 not available
#
#                                              address  floorNum      facing  \
# 0  Sector 89,gurgaon, Sector 89 Gurgaon, Gurgaon,...      14.0  North-East
# 1                Sector 69 Gurgaon, Gurgaon, Haryana       0.0        East
# 2                      Palam Vihar, Gurgaon, Haryana       3.0        East
# 3                Sector 9A Gurgaon, Gurgaon, Haryana       3.0         NaN
# 4          602, Sector 37D Gurgaon, Gurgaon, Haryana       6.0        West
#
#      agePossession                                    nearbyLocations  \
# 0        undefined                                                NaN
# 1  1 to 5 Year Old  ['Airia Mall Sector 68', 'Southern Peripheral ...
# 2     10+ Year Old  ['Palam Vihar Vyapar kendra', 'Palam triangle'...
# 3  1 to 5 Year Old  ['Chintapurni Mandir', 'State bank ATM', 'Esic...
# 4  1 to 5 Year Old  ['Airia Mall', 'Dwarka Expressway', 'Golf Cour...
#
#                                          description  \
# 0  2bhk residential house for new property in 3c ...
# 1  This beautiful 3 bhk flat in sector 69 gurgaon...
# 2  Very nicely built up independent duplex house ...
# 3  Walking distance from market, schools, banks, ...
# 4  This lovely 4 bhk apartment/flat in sector 37d...
#
#                                       furnishDetails  \
# 0  ['1 Light', 'No AC', 'No Bed', 'No Chimney', '...
# 1  ['3 Wardrobe', '6 Fan', '1 Exhaust Fan', '1 Di...
# 2  ['7 Wardrobe', '12 Fan', '1 Exhaust Fan', '7 G...
# 3  ['11 Wardrobe', '18 Fan', '1 Exhaust Fan', '5 ...
# 4  ['6 Fan', '19 Light', '5 AC', '1 Chimney', '1 ...
#
#                                             features  \
# 0                                                NaN
# 1  ['Centrally Air Conditioned', 'Water purifier'...
# 2  ['Feng Shui / Vaastu Compliant', 'Private Gard...
# 3  ['Private Garden / Terrace', 'Water Storage', ...
# 4  ['Centrally Air Conditioned', 'Water purifier'...
#
#                                               rating
# 0  ['Environment4 out of 5', 'Lifestyle4 out of 5...
# 1  ['Green Area5 out of 5', 'Construction4 out of...
# 2  ['Environment5 out of 5', 'Lifestyle5 out of 5...
# 3  ['Environment4 out of 5', 'Lifestyle4 out of 5...
# 4  ['Green Area4.5 out of 5', 'Construction4.5 ou...

# %%
df.to_csv('gurgaon_properties.csv',index=False)
